# %%
import pandas as pd
from label_util import LabelingTool
import os

# %%
# read data
df = pd.read_csv('flux_def.csv')
df = df.set_index('wordnet_id')

# %%
labeler = LabelingTool(
    dataset=df,
    assessor_id='name', 
    image_path='imagepath',
    save2path='output_path.csv',
    img_type='.png'
    )

# %%
labeler.label_samples()

# %%
output = pd.read_csv('test_output_def.csv', index_col=0) # chack that it is saved
